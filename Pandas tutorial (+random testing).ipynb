# %%
import pandas as pd

# %%
pd.DataFrame({'Yes': [50, 21], 'No': [131, 2]}, index=['Product A', 'Product B'])
# Out:
#            Yes   No
# Product A   50  131
# Product B   21    2

# %% [markdown]
# A Series is, in essence, a single column of a DataFrame

# %%
pd.Series([1, 2, 3, 4, 5])
s = pd.Series([3, -5, 7, 4], index=['a', 'b', 'c', 'd'])
s

data = {'Country': ['Belgium', 'India', 'Brazil'],
 'Capital': ['Brussels', 'New Delhi', 'Brasília'],
 'Population': [11190846, 1303171035, 207847528]}

df = pd.DataFrame(data,
 columns=['Country', 'Capital', 'Population'])
df
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels    11190846
# 1    India  New Delhi  1303171035
# 2   Brazil   Brasília   207847528

# %%
s
# Out:
# a    3
# b   -5
# c    7
# d    4
# dtype: int64

# %%
df[1:]
df.iloc[[0],[0]] 
type(df.loc[[0], ['Country']].iloc[0])
df.iloc[0]
df.ix[1,'Capital']
# Out:
# c:\users\sival\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """
# 'New Delhi'

# %%
df.values[0][1]
# Out:
# 'Brussels'

# %%
s[~(s > 1)]
s>1
# Out:
# a     True
# b    False
# c     True
# d     True
# dtype: bool

# %%
s['a'] = 6
s
# Out:
# a    6
# b   -5
# c    7
# d    4
# dtype: int64

# %%
df.drop('Country', axis=1)
df
df2 = df.reindex([4,3,2],)

# %%
df2.sort_index()
df2
# Out:
#   Country   Capital   Population
# 4     NaN       NaN          NaN
# 3     NaN       NaN          NaN
# 2  Brazil  Brasília  207847528.0

# %%
df.sort_values(by='Country')
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels    11190846
# 2   Brazil   Brasília   207847528
# 1    India  New Delhi  1303171035

# %%
df.rank()
# Out:
#    Country  Capital  Population
# 0      1.0      2.0         1.0
# 1      3.0      3.0         3.0
# 2      2.0      1.0         2.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
# Country       3 non-null object
# Capital       3 non-null object
# Population    3 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 152.0+ bytes

# %%
df2.count()
# Out:
# Country       1
# Capital       1
# Population    1
# dtype: int64

# %%
df.min()
# Out:
# Country        Belgium
# Capital       Brasília
# Population    11190846
# dtype: object

# %%
df.sum()
# Out:
# Country              BelgiumIndiaBrazil
# Capital       BrusselsNew DelhiBrasília
# Population                   1522209409
# dtype: object

# %%
f = lambda x: x*2
df.apply(f)
df.applymap(f)
# Out:
#           Country             Capital  Population
# 0  BelgiumBelgium    BrusselsBrussels    22381692
# 1      IndiaIndia  New DelhiNew Delhi  2606342070
# 2    BrazilBrazil    BrasíliaBrasília   415695056

# %% [markdown]
# ### Checking if column set is uniquely identify row

# %%
df1 = pd.DataFrame([(1,2),(1,2)], columns=list('AB'))
# df2 = pd.DataFrame([(1,2),(1,3)], columns=list('AB'))
df1
print(df1.set_index(['A','B']).index.is_unique)
# Out:
# False

# %% [markdown]
# # PANDAS ADVANCED
#
# - https://towardsdatascience.com/learn-advanced-features-for-pythons-main-data-analysis-library-in-20-minutes-d0eedd90d086

# %% [markdown]
# ### 1) datatypes

# %%
invoices = pd.read_csv('https://raw.githubusercontent.com/FBosler/you-datascientist/master/invoices.csv')
invoices
# Out:
#                Order Id        Date           Meal Id        Company Id  \
# 0      839FKFW2LLX4LMBB  2016-05-27  INBUX904GIHI8YBD  LJKS5NK6788CYMUU
# 1      97OX39BGVMHODLJM  2018-09-27  J0MMOOPP709DIDIE  LJKS5NK6788CYMUU
# 2      041ORQM5OIHTIU6L  2014-08-24  E4UJLQNCI16UX5CS  LJKS5NK6788CYMUU
# 3      YT796QI18WNGZ7ZJ  2014-04-12  C9SDFHF7553BE247  LJKS5NK6788CYMUU
# 4      6YLROQT27B6HRF4E  2015-07-28  48EQXS6IHYNZDDZ5  LJKS5NK6788CYMUU
# 5      AT0R4DFYYAFOC88Q  2014-07-21  W48JPR1UYWJ18NC6  LJKS5NK6788CYMUU
# 6      2DDN2LHS7G85GKPQ  2014-04-29  1MKLAKBOE3SP7YUL  LJKS5NK6788CYMUU
# 7      FM608JK1N01BPUQN  2014-05-08  E8WJZ1FOSKZD2MJN  36MFTZOYMTAJP1RK
# 8      CK331XXNIBQT81QL  2015-05-23  CTZSFFKQTY7SBZ4J  36MFTZOYMTAJP1RK
# 9      FESGKOQN2OZZWXY3  2016-01-10  US0NQYNNHS1SQJ4S  36MFTZOYMTAJP1RK
# 10     YITOTLOF0MWZ0VYX  2016-10-03  RGYX8772307H78ON  36MFTZOYMTAJP1RK
# 11     8RIGCF74GUEQHQEE  2018-07-23  5XK0KTFTD6OAP9ZP  36MFTZOYMTAJP1RK
# ...

# %%
invoices.shape
# Out:
# (50017, 9)

# %%
invoices.dtypes
# Out:
# Order Id              object
# Date                  object
# Meal Id               object
# Company Id            object
# Date of Meal          object
# Participants          object
# Meal Price           float64
# Type of Meal          object
# Heroes Adjustment       bool
# dtype: object

# %%
invoices['Type of Meal'] = invoices['Type of Meal'].astype('category')
invoices['Date'] = invoices['Date'].astype('datetime64')
invoices['Meal Price'] = invoices['Meal Price'].astype('int')
invoices.dtypes
# Out:
# Order Id                     object
# Date                 datetime64[ns]
# Meal Id                      object
# Company Id                   object
# Date of Meal                 object
# Participants                 object
# Meal Price                    int32
# Type of Meal               category
# Heroes Adjustment              bool
# dtype: object

# %%
invoices.loc[45612,'Meal Price'] = 'I am causing trouble'
invoices.dtypes
# Out:
# Order Id                     object
# Date                 datetime64[ns]
# Meal Id                      object
# Company Id                   object
# Date of Meal                 object
# Participants                 object
# Meal Price                   object
# Type of Meal               category
# Heroes Adjustment              bool
# dtype: object

# %%
invoices['Meal Price'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-7a45f8f5d74c> in <module>()
# ----> 1 invoices['Meal Price'].astype(int)
#
# c:\users\sival\appdata\local\programs\python\python36\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5689             # else, only a single dtype is given
#    5690             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5691                                          **kwargs)
#    5692             return self._constructor(new_data).__finalize__(self)
#    5693
#
# c:\users\sival\appdata\local\programs\python\python36\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, **kwargs)
#     529
#     530     def astype(self, dtype, **kwargs):
# --> 531         return self.apply('astype', dtype=dtype, **kwargs)
#     532
# ...

# %%
invoices['Meal Price'].apply(lambda x: type(x)).value_counts()
# Out:
# <class 'int'>    50016
# <class 'str'>        1
# Name: Meal Price, dtype: int64

# %%
invoices['Meal Price'][invoices['Meal Price'].apply(
  lambda x: isinstance(x,str)
)]
# Out:
# 45612    I am causing trouble
# Name: Meal Price, dtype: object

# %%
# invoices['Meal Price'].astype(int)
invoices['Meal Price'] = pd.to_numeric(invoices['Meal Price'],errors='coerce')

# %%
invoices['Date of Meal'] = pd.to_datetime(invoices['Date of Meal'], utc=True)

# %%
invoices.dtypes
# Out:
# Order Id                          object
# Date                      datetime64[ns]
# Meal Id                           object
# Company Id                        object
# Date of Meal         datetime64[ns, UTC]
# Participants                      object
# Meal Price                       float64
# Type of Meal                    category
# Heroes Adjustment                   bool
# dtype: object

# %% [markdown]
# ### Accessors

# %%
invoices['Date'].dt.weekday_name.head()
# Out:
# 0      Friday
# 1    Thursday
# 2      Sunday
# 3    Saturday
# 4     Tuesday
# Name: Date, dtype: object

# %%
invoices['Type of Meal'].str.upper().head()
# Out:
# 0    BREAKFAST
# 1       DINNER
# 2        LUNCH
# 3       DINNER
# 4        LUNCH
# Name: Type of Meal, dtype: object

# %% [markdown]
# ### Combining dfs

# %%
invoices.head()
# Out:
#            Order Id       Date           Meal Id        Company Id  \
# 0  839FKFW2LLX4LMBB 2016-05-27  INBUX904GIHI8YBD  LJKS5NK6788CYMUU
# 1  97OX39BGVMHODLJM 2018-09-27  J0MMOOPP709DIDIE  LJKS5NK6788CYMUU
# 2  041ORQM5OIHTIU6L 2014-08-24  E4UJLQNCI16UX5CS  LJKS5NK6788CYMUU
# 3  YT796QI18WNGZ7ZJ 2014-04-12  C9SDFHF7553BE247  LJKS5NK6788CYMUU
# 4  6YLROQT27B6HRF4E 2015-07-28  48EQXS6IHYNZDDZ5  LJKS5NK6788CYMUU
#
#                Date of Meal                       Participants  Meal Price  \
# 0 2016-05-31 05:00:00+00:00                   ['David Bishop']       469.0
# 1 2018-10-01 18:00:00+00:00                   ['David Bishop']        22.0
# 2 2014-08-23 12:00:00+00:00                 ['Karen Stansell']       314.0
# 3 2014-04-07 19:00:00+00:00                   ['Addie Patino']       438.0
# 4 2015-07-27 12:00:00+00:00  ['Addie Patino' 'Susan Guerrero']       690.0
#
#   Type of Meal  Heroes Adjustment
# 0    Breakfast              False
# 1       Dinner              False
# ...

# %%
y_2013 = invoices[invoices['Date of Meal'].dt.year == 2013].copy()
y_2014 = invoices[invoices['Date of Meal'].dt.year == 2014].copy()
y_2015 = invoices[invoices['Date of Meal'].dt.year == 2015].copy()
y_2016 = invoices[invoices['Date of Meal'].dt.year == 2016].copy()
y_2017 = invoices[invoices['Date of Meal'].dt.year == 2017].copy()
y_2018 = invoices[invoices['Date of Meal'].dt.year == 2018].copy()
y_2019 = invoices[invoices['Date of Meal'].dt.year == 2019].copy()

# %%
pd.concat([y_2013,y_2014,y_2015,y_2016,y_2017,y_2018,y_2019])
# Out:
#                Order Id       Date           Meal Id        Company Id  \
# 1449   HH1CUKNKIIK87D4L 2014-01-03  M4QG9N01E25U3A53  N4BN0GG5XKZV113C
# 4256   KFXTYDP0YG9C6AZF 2014-01-03  RUMIZCB9KM3N57BN  9FOCJR50GUHXT2S0
# 4747   D5NR6EP8NQZ0TGW6 2014-01-05  5GDXSLG0F4WA3JEZ  RJ1NLTCTP1COK3YS
# 5097   2T71YISMHMPBKE3Z 2014-01-03  0C7DIKEPG5KXNRFR  R835HX2AVB1KJJL0
# 5154   V226RP8DLAQQKU51 2014-01-04  6C9WDEPC4Q05WBSR  23B3R2N3LSYQJQMF
# 5541   1RAY4TP6J8DRMSXT 2014-01-01  LMXU5RSC8ZNWTBOP  VPD6H4AO65BVL5KC
# 5649   GNPLLBY3YVJQI761 2014-01-01  8356KZDF61SJANC1  JA417QYUX0L6CXWK
# 6397   WNNM9HQY7B2L0JVB 2014-01-01  1T3H328F25HIQ44I  8PYQ11TLQ9H08AU9
# 8522   X1TIG78KOYJ6JZE9 2014-01-01  MF7SRNYI9NJGYRNY  2R7MJ6H719F1KL10
# 10973  T0C02X9NTU1JFT2D 2014-01-01  ATEOZK0GAHD9ENY0  NEKQGUFI5NTOWUZY
# 13160  MSDXPD33SX7YVV2X 2014-01-01  BRNCVHS0RX58VGVK  7VKN3I1E8Q73O27K
# 13994  MLJU1YPB47OUELTQ 2014-01-04  YQNF6BK81S1869UV  G4ENF5DPW2OQOKKY
# ...

# %% [markdown]
# ### Merging
# - diff from concat, this is merge wrt to one common column

# %%
invoices.head(3)
# Out:
#            Order Id       Date           Meal Id        Company Id  \
# 0  839FKFW2LLX4LMBB 2016-05-27  INBUX904GIHI8YBD  LJKS5NK6788CYMUU
# 1  97OX39BGVMHODLJM 2018-09-27  J0MMOOPP709DIDIE  LJKS5NK6788CYMUU
# 2  041ORQM5OIHTIU6L 2014-08-24  E4UJLQNCI16UX5CS  LJKS5NK6788CYMUU
#
#                Date of Meal        Participants  Meal Price Type of Meal  \
# 0 2016-05-31 05:00:00+00:00    ['David Bishop']       469.0    Breakfast
# 1 2018-10-01 18:00:00+00:00    ['David Bishop']        22.0       Dinner
# 2 2014-08-23 12:00:00+00:00  ['Karen Stansell']       314.0        Lunch
#
#    Heroes Adjustment
# 0              False
# 1              False
# 2              False

# %%
order_data = pd.read_csv('https://raw.githubusercontent.com/FBosler/you-datascientist/master/order_leads.csv', parse_dates=[3])
order_data.head()
# Out:
#            Order Id        Company Id            Company Name       Date  \
# 0  80EYLOKP9E762WKG  LJKS5NK6788CYMUU  Chimera-Chasing Casbah 2017-02-18
# 1  TLEXR1HZWTUTBHPB  LJKS5NK6788CYMUU  Chimera-Chasing Casbah 2015-07-30
# 2  839FKFW2LLX4LMBB  LJKS5NK6788CYMUU  Chimera-Chasing Casbah 2016-05-27
# 3  97OX39BGVMHODLJM  LJKS5NK6788CYMUU  Chimera-Chasing Casbah 2018-09-27
# 4  5T4LGH4XGBWOD49Z  LJKS5NK6788CYMUU  Chimera-Chasing Casbah 2016-01-14
#
#    Order Value  Converted
# 0         4875          1
# 1         8425          0
# 2         4837          0
# 3          343          0
# 4          983          0

# %%
sales_team = pd.read_csv('https://raw.githubusercontent.com/FBosler/you-datascientist/master/sales_team.csv')
sales_team.head()
# Out:
#            Sales Rep      Sales Rep Id                    Company Name  \
# 0  Jessie Mcallister  97UNNAT790E0WM4N          Chimera-Chasing Casbah
# 1  Jessie Mcallister  97UNNAT790E0WM4N                Tangential Sheds
# 2  Jessie Mcallister  97UNNAT790E0WM4N                   Two-Mile Grab
# 3  Jessie Mcallister  97UNNAT790E0WM4N  Three-Men-And-A-Helper Congo'S
# 4  Jessie Mcallister  97UNNAT790E0WM4N        Biophysical Battleground
#
#          Company Id
# 0  LJKS5NK6788CYMUU
# 1  36MFTZOYMTAJP1RK
# 2  H3JRC7XX7WJAD4ZO
# 3  HB25MDZR0MGCQUGX
# 4  7RVA8TIVBLBXMNO4

# %%
df1 = pd.DataFrame([(12,2),(13,1), (11,1)], columns=list('AB'))
df2 = pd.DataFrame([(20,2),(30,2)], columns=list('CB'))
df1
pd.merge(df1,df2, left_index=True, right_index=True)
# df1.set_index(['A','B']).index
# print(df1.set_index(['A','B']).index.is_unique)
# Out:
#     A  B_x   C  B_y
# 0  12    2  20    2
# 1  13    1  30    2

# %% [markdown]
# ### Reshaping

# %%
invoices['Meal Price'].values
# Out:
# array([469.,  22., 314., ..., 160., 497., 365.])

# %%
pd.get_dummies(invoices['Type of Meal']).mul(invoices['Meal Price'].values,axis=0)
# Out:
#        Breakfast  Dinner  Lunch
# 0          469.0     0.0    0.0
# 1            0.0    22.0    0.0
# 2            0.0     0.0  314.0
# 3            0.0   438.0    0.0
# 4            0.0     0.0  690.0
# 5            0.0   181.0    0.0
# 6            0.0    14.0    0.0
# 7          320.0     0.0    0.0
# 8            0.0     0.0  697.0
# 9            0.0   451.0    0.0
# 10           0.0   263.0    0.0
# 11         210.0     0.0    0.0
# 12         755.0     0.0    0.0
# 13           0.0     0.0  469.0
# 14           0.0     0.0  502.0
# 15           0.0     0.0  829.0
# 16           0.0   708.0    0.0
# 17         475.0     0.0    0.0
# 18           0.0     0.0   27.0
# 19           0.0     0.0  672.0
# 20           0.0     0.0  552.0
# 21         191.0     0.0    0.0
# 22         471.0     0.0    0.0
# 23           0.0   588.0    0.0
# 24           0.0     0.0   98.0
# 25         516.0     0.0    0.0
# 26         664.0     0.0    0.0
# 27         323.0     0.0    0.0
# ...

# %%
melt_experiment = pd.merge(
    invoices,
    pd.get_dummies(invoices['Type of Meal']).mul(invoices['Meal Price'].values,axis=0),
    left_index=True,
    right_index=True
)
del melt_experiment['Type of Meal']
del melt_experiment['Meal Price']
melt_experiment.head()
# Out:
#            Order Id       Date           Meal Id        Company Id  \
# 0  839FKFW2LLX4LMBB 2016-05-27  INBUX904GIHI8YBD  LJKS5NK6788CYMUU
# 1  97OX39BGVMHODLJM 2018-09-27  J0MMOOPP709DIDIE  LJKS5NK6788CYMUU
# 2  041ORQM5OIHTIU6L 2014-08-24  E4UJLQNCI16UX5CS  LJKS5NK6788CYMUU
# 3  YT796QI18WNGZ7ZJ 2014-04-12  C9SDFHF7553BE247  LJKS5NK6788CYMUU
# 4  6YLROQT27B6HRF4E 2015-07-28  48EQXS6IHYNZDDZ5  LJKS5NK6788CYMUU
#
#                Date of Meal                       Participants  \
# 0 2016-05-31 05:00:00+00:00                   ['David Bishop']
# 1 2018-10-01 18:00:00+00:00                   ['David Bishop']
# 2 2014-08-23 12:00:00+00:00                 ['Karen Stansell']
# 3 2014-04-07 19:00:00+00:00                   ['Addie Patino']
# 4 2015-07-27 12:00:00+00:00  ['Addie Patino' 'Susan Guerrero']
#
#    Heroes Adjustment  Breakfast  Dinner  Lunch
# 0              False      469.0     0.0    0.0
# 1              False        0.0    22.0    0.0
# ...

# %% [markdown]
# ### groupby

# %%
import numpy as np
# invoices.groupby(['Company Id','Type of Meal']).agg(
#     {'Meal Price':np.mean}
# )

invoices.groupby(['Company Id','Type of Meal']).agg(
    Avg_Price = pd.NamedAgg(column='Meal Price', aggfunc=np.mean)
)

# %%
pd.pivot_table(
    invoices,
    index=['Company Id','Type of Meal'],
    values='Meal Price',
    aggfunc=np.mean,
    margins=True
).head()
# Out:
#                                Meal Price
# Company Id       Type of Meal
# 007RF0BCBVMXTL80 Breakfast     301.666667
#                  Dinner        453.000000
#                  Lunch         112.000000
# 00CVEIVO8C92FFBO Breakfast     346.500000
#                  Dinner        425.000000

# %%
stack_test = invoices.groupby(['Company Id','Type of Meal']).agg({
    'Meal Price':[max,min,np.mean],
    'Date of Meal':[max,min],
})
stack_test.head(10)
# Out:
#                               Meal Price                     \
#                                      max    min        mean
# Company Id       Type of Meal
# 007RF0BCBVMXTL80 Breakfast         545.0   74.0  301.666667
#                  Dinner            729.0  156.0  453.000000
#                  Lunch             112.0  112.0  112.000000
# 00CVEIVO8C92FFBO Breakfast         606.0  142.0  346.500000
#                  Dinner            631.0  234.0  425.000000
#                  Lunch             785.0   92.0  426.428571
# 00OFNRZV8983KC3L Breakfast         748.0  395.0  571.500000
#                  Dinner            764.0  536.0  665.333333
#                  Lunch             370.0  344.0  357.000000
# 00R1H0DBLAVXHOTZ Breakfast         778.0  778.0  778.000000
#
#                                            Date of Meal  \
#                                                     max
# Company Id       Type of Meal
# 007RF0BCBVMXTL80 Breakfast    2015-09-17 06:00:00+00:00
# ...

# %%
invoices.describe()
# Out:
#          Meal Price
# count  50017.000000
# mean     403.256713
# std      234.128913
# min        6.000000
# 25%      204.000000
# 50%      398.000000
# 75%      593.000000
# max     1065.000000

# %%
invoices['Type of Meal'].value_counts().head()
# Out:
# Dinner       16732
# Breakfast    16663
# Lunch        16622
# Name: Type of Meal, dtype: int64

# %%
invoices.describe(include='all')
# Out:
#                 Order Id                 Date           Meal Id  \
# count              50017                50017             50017
# unique             50017                 1826             50017
# top     B4BKZE4SYAX13SHN  2018-06-21 00:00:00  MRGM4WPCONQ5HJUZ
# freq                   1                   47                 1
# first                NaN  2014-01-01 00:00:00               NaN
# last                 NaN  2018-12-31 00:00:00               NaN
# mean                 NaN                  NaN               NaN
# std                  NaN                  NaN               NaN
# min                  NaN                  NaN               NaN
# 25%                  NaN                  NaN               NaN
# 50%                  NaN                  NaN               NaN
# 75%                  NaN                  NaN               NaN
# max                  NaN                  NaN               NaN
#
# ...

# %%
'sdf jacket'.strip()
# Out:
# 'sdf jacket'
